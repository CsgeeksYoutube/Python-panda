# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.read_csv("regex.txt")
# Out:
#                        Name  Age M/F           City State Country  \
# 0          Kirui, Geoffrey    24   M       Keringet   NaN     KEN
# 1            Rupp, Galen      30   M       Portland    OR     USA
# 2           Osako, Suguru     25   M   Machida-City   NaN     JPN
# 3          Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4            Chebet, Wilson   31   M       Marakwet   NaN     KEN
# ..                      ...  ...  ..            ...   ...     ...
# 64          Gray, Samuel R.   21   M         Exeter    NH     USA
# 65           Gilmore, Peter   27   M         Boston    MA     USA
# 66  Fallas Navarro, Juan R.   31   M    Shasta Lake    CA     USA
# 67            Thomas, Jason   22   M      Urbandale    IA     USA
# 68        Whitty, Fergal M.   41   M         Dublin   NaN     IRL
#
#    Official Time  Overall  Gender Years Ran
# 0        2:09:37        1       1       NaN
# 1        2:09:58        2       2       NaN
# ...

# %%
dfb=pd.read_csv("regex.txt")

# %%
dfb
# Out:
#                        Name  Age M/F           City State Country  \
# 0          Kirui, Geoffrey    24   M       Keringet   NaN     KEN
# 1            Rupp, Galen      30   M       Portland    OR     USA
# 2           Osako, Suguru     25   M   Machida-City   NaN     JPN
# 3          Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4            Chebet, Wilson   31   M       Marakwet   NaN     KEN
# ..                      ...  ...  ..            ...   ...     ...
# 64          Gray, Samuel R.   21   M         Exeter    NH     USA
# 65           Gilmore, Peter   27   M         Boston    MA     USA
# 66  Fallas Navarro, Juan R.   31   M    Shasta Lake    CA     USA
# 67            Thomas, Jason   22   M      Urbandale    IA     USA
# 68        Whitty, Fergal M.   41   M         Dublin   NaN     IRL
#
#    Official Time  Overall  Gender Years Ran
# 0        2:09:37        1       1       NaN
# 1        2:09:58        2       2       NaN
# ...

# %%
dfb.City
# Out:
# 0          Keringet
# 1          Portland
# 2      Machida-City
# 3     Mammoth Lakes
# 4          Marakwet
#           ...
# 64           Exeter
# 65           Boston
# 66      Shasta Lake
# 67        Urbandale
# 68           Dublin
# Name: City, Length: 69, dtype: object

# %%
dfb.City.str.upper()
# Out:
# 0          KERINGET
# 1          PORTLAND
# 2      MACHIDA-CITY
# 3     MAMMOTH LAKES
# 4          MARAKWET
#           ...
# 64           EXETER
# 65           BOSTON
# 66      SHASTA LAKE
# 67        URBANDALE
# 68           DUBLIN
# Name: City, Length: 69, dtype: object

# %%
dfb.City.str.lower()
# Out:
# 0          keringet
# 1          portland
# 2      machida-city
# 3     mammoth lakes
# 4          marakwet
#           ...
# 64           exeter
# 65           boston
# 66      shasta lake
# 67        urbandale
# 68           dublin
# Name: City, Length: 69, dtype: object

# %%
dfb.City.str.swapcase()
# Out:
# 0          kERINGET
# 1          pORTLAND
# 2      mACHIDA-cITY
# 3     mAMMOTH lAKES
# 4          mARAKWET
#           ...
# 64           eXETER
# 65           bOSTON
# 66      sHASTA lAKE
# 67        uRBANDALE
# 68           dUBLIN
# Name: City, Length: 69, dtype: object

# %%
dfb.City.str.capitalize()
# Out:
# 0          Keringet
# 1          Portland
# 2      Machida-city
# 3     Mammoth lakes
# 4          Marakwet
#           ...
# 64           Exeter
# 65           Boston
# 66      Shasta lake
# 67        Urbandale
# 68           Dublin
# Name: City, Length: 69, dtype: object

# %%
dfb.Name.str.find('Andy').value_counts()
# Out:
# -1    69
# Name: Name, dtype: int64

# %%
dfb.Name.str.find('James').value_counts()
# Out:
# -1    69
# Name: Name, dtype: int64

# %%
dfb.Name.iloc[0]
# Out:
# ' Kirui, Geoffrey '

# %%
dfb.Name.iloc[1]
# Out:
# 'Rupp, Galen   '

# %%
dfb.Name.iloc[0:4].str.strip()
# Out:
# 0     Kirui, Geoffrey
# 1         Rupp, Galen
# 2       Osako, Suguru
# 3    Biwott, Shadrack
# Name: Name, dtype: object

# %%
dfb.Name= dfb.Name.str.strip()

# %%
dfb
# Out:
#                        Name  Age M/F           City State Country  \
# 0           Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1               Rupp, Galen   30   M       Portland    OR     USA
# 2             Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3          Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4            Chebet, Wilson   31   M       Marakwet   NaN     KEN
# ..                      ...  ...  ..            ...   ...     ...
# 64          Gray, Samuel R.   21   M         Exeter    NH     USA
# 65           Gilmore, Peter   27   M         Boston    MA     USA
# 66  Fallas Navarro, Juan R.   31   M    Shasta Lake    CA     USA
# 67            Thomas, Jason   22   M      Urbandale    IA     USA
# 68        Whitty, Fergal M.   41   M         Dublin   NaN     IRL
#
#    Official Time  Overall  Gender Years Ran
# 0        2:09:37        1       1       NaN
# 1        2:09:58        2       2       NaN
# ...

# %%
dfb.Name.iloc[0]
# Out:
# 'Kirui, Geoffrey'

# %%
dfb.Name.iloc[1]
# Out:
# 'Rupp, Galen'

# %%
dfb.Name.str.split(', ')
# Out:
# 0             [Kirui, Geoffrey]
# 1                 [Rupp, Galen]
# 2               [Osako, Suguru]
# 3            [Biwott, Shadrack]
# 4              [Chebet, Wilson]
#                 ...
# 64            [Gray, Samuel R.]
# 65             [Gilmore, Peter]
# 66    [Fallas Navarro, Juan R.]
# 67              [Thomas, Jason]
# 68          [Whitty, Fergal M.]
# Name: Name, Length: 69, dtype: object

# %%
dfb.Name.str.split(', ')[0]
# Out:
# ['Kirui', 'Geoffrey']

# %%
dfb.Name.str.split(', ').str.get(0)
# Out:
# 0              Kirui
# 1               Rupp
# 2              Osako
# 3             Biwott
# 4             Chebet
#            ...
# 64              Gray
# 65           Gilmore
# 66    Fallas Navarro
# 67            Thomas
# 68            Whitty
# Name: Name, Length: 69, dtype: object

# %%
dfb['First Name']= dfb.Name.str.split(', ').str.get(1)
dfb['Last Name'] = dfb.Name.str.split(', ').str.get(0)

# %%
dfb
# Out:
#                        Name  Age M/F           City State Country  \
# 0           Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1               Rupp, Galen   30   M       Portland    OR     USA
# 2             Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3          Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4            Chebet, Wilson   31   M       Marakwet   NaN     KEN
# ..                      ...  ...  ..            ...   ...     ...
# 64          Gray, Samuel R.   21   M         Exeter    NH     USA
# 65           Gilmore, Peter   27   M         Boston    MA     USA
# 66  Fallas Navarro, Juan R.   31   M    Shasta Lake    CA     USA
# 67            Thomas, Jason   22   M      Urbandale    IA     USA
# 68        Whitty, Fergal M.   41   M         Dublin   NaN     IRL
#
#    Official Time  Overall  Gender Years Ran First Name       Last Name
# 0        2:09:37        1       1       NaN   Geoffrey           Kirui
# ...

# %%
dfb['M/F'].str.cat(dfb.Age.astype(str),sep='_')
# Out:
# 0     M_24
# 1     M_30
# 2     M_25
# 3     M_32
# 4     M_31
#       ...
# 64    M_21
# 65    M_27
# 66    M_31
# 67    M_22
# 68    M_41
# Name: M/F, Length: 69, dtype: object

# %%
dfb.drop(['First Name','Last Name'],axis=1, inplace=True)

# %%
dfb.head()
# Out:
#                Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN       2:09:37
# 1       Rupp, Galen   30   M       Portland    OR     USA       2:09:58
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN       2:10:28
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
dfb.Name.str.split(', ',expand=True)
# Out:
#                  0          1
# 0            Kirui   Geoffrey
# 1             Rupp      Galen
# 2            Osako     Suguru
# 3           Biwott   Shadrack
# 4           Chebet     Wilson
# ..             ...        ...
# 64            Gray  Samuel R.
# 65         Gilmore      Peter
# 66  Fallas Navarro    Juan R.
# 67          Thomas      Jason
# 68          Whitty  Fergal M.
#
# [69 rows x 2 columns]

# %%
dfb.Name.str.split(', ')
# Out:
# 0             [Kirui, Geoffrey]
# 1                 [Rupp, Galen]
# 2               [Osako, Suguru]
# 3            [Biwott, Shadrack]
# 4              [Chebet, Wilson]
#                 ...
# 64            [Gray, Samuel R.]
# 65             [Gilmore, Peter]
# 66    [Fallas Navarro, Juan R.]
# 67              [Thomas, Jason]
# 68          [Whitty, Fergal M.]
# Name: Name, Length: 69, dtype: object

# %%
dfb.Name.str.split(expand=True)
# Out:
#            0         1     2     3
# 0     Kirui,  Geoffrey  None  None
# 1      Rupp,     Galen  None  None
# 2     Osako,    Suguru  None  None
# 3    Biwott,  Shadrack  None  None
# 4    Chebet,    Wilson  None  None
# ..       ...       ...   ...   ...
# 64     Gray,    Samuel    R.  None
# 65  Gilmore,     Peter  None  None
# 66    Fallas  Navarro,  Juan    R.
# 67   Thomas,     Jason  None  None
# 68   Whitty,    Fergal    M.  None
#
# [69 rows x 4 columns]

# %%
dfb.Name.str.split(expand=True).count(axis=1)==3
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64     True
# 65    False
# 66    False
# 67    False
# 68     True
# Length: 69, dtype: bool

# %%
dfb.Name[dfb.Name.str.split(expand=True).count(axis=1)==4]
# Out:
# 66    Fallas Navarro, Juan R.
# Name: Name, dtype: object

# %%
dfb.Name.str.split(expand=True, n=1)
# Out:
#            0                 1
# 0     Kirui,          Geoffrey
# 1      Rupp,             Galen
# 2     Osako,            Suguru
# 3    Biwott,          Shadrack
# 4    Chebet,            Wilson
# ..       ...               ...
# 64     Gray,         Samuel R.
# 65  Gilmore,             Peter
# 66    Fallas  Navarro, Juan R.
# 67   Thomas,             Jason
# 68   Whitty,         Fergal M.
#
# [69 rows x 2 columns]

# %%
dfb[['First Name','Last Name']]= dfb.Name.str.split(', ',expand=True)

# %%
dfb
# Out:
#                        Name  Age M/F           City State Country  \
# 0           Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1               Rupp, Galen   30   M       Portland    OR     USA
# 2             Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3          Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4            Chebet, Wilson   31   M       Marakwet   NaN     KEN
# ..                      ...  ...  ..            ...   ...     ...
# 64          Gray, Samuel R.   21   M         Exeter    NH     USA
# 65           Gilmore, Peter   27   M         Boston    MA     USA
# 66  Fallas Navarro, Juan R.   31   M    Shasta Lake    CA     USA
# 67            Thomas, Jason   22   M      Urbandale    IA     USA
# 68        Whitty, Fergal M.   41   M         Dublin   NaN     IRL
#
#    Official Time  Overall  Gender Years Ran      First Name  Last Name
# 0        2:09:37        1       1       NaN           Kirui   Geoffrey
# ...
