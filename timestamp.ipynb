# %%
import pandas as pd

# %%
pd.Timestamp("4th of may 1998")
# Out:
# Timestamp('1998-05-04 00:00:00')

# %%
pdts= pd.to_datetime('4/7/1776',dayfirst=True)

# %%
pdts
# Out:
# Timestamp('1776-07-04 00:00:00')

# %%
pdts.day_name()
# Out:
# 'Thursday'

# %%
pdts.days_in_month
# Out:
# 31

# %%
pdts.quarter
# Out:
# 3

# %%
df4= pd.read_csv("new_text_file.txt")

# %%
df4
# Out:
#           Date  Price
# 0    19-Nov-18  64.14
# 1    20-Nov-18  61.50
# 2    21-Nov-18  61.65
# 3    22-Nov-18  61.11
# 4    23-Nov-18  57.69
# ..         ...    ...
# 214  24-Sep-19  64.13
# 215  25-Sep-19  62.41
# 216  26-Sep-19  62.08
# 217  27-Sep-19  62.48
# 218  30-Sep-19  60.99
#
# [219 rows x 2 columns]

# %%
df4.dtypes
# Out:
# Date      object
# Price    float64
# dtype: object

# %%
df4.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    219 non-null    object
#  1   Price   219 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 16.0 KB

# %%
import numpy as np

# %%
df4.Date=df4.Date.astype(np.datetime64)

# %%
df4
# Out:
#           Date  Price
# 0   2018-11-19  64.14
# 1   2018-11-20  61.50
# 2   2018-11-21  61.65
# 3   2018-11-22  61.11
# 4   2018-11-23  57.69
# ..         ...    ...
# 214 2019-09-24  64.13
# 215 2019-09-25  62.41
# 216 2019-09-26  62.08
# 217 2019-09-27  62.48
# 218 2019-09-30  60.99
#
# [219 rows x 2 columns]

# %%
df4.dtypes
# Out:
# Date     datetime64[ns]
# Price           float64
# dtype: object

# %%
df4.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    219 non-null    datetime64[ns]
#  1   Price   219 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.5 KB

# %%
df4.set_index('Date',inplace=True)

# %%
df4.head()
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-20  61.50
# 2018-11-21  61.65
# 2018-11-22  61.11
# 2018-11-23  57.69

# %%
df4.index
# Out:
# DatetimeIndex(['2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22',
#                '2018-11-23', '2018-11-26', '2018-11-27', '2018-11-28',
#                '2018-11-29', '2018-11-30',
#                ...
#                '2019-09-17', '2019-09-18', '2019-09-19', '2019-09-20',
#                '2019-09-23', '2019-09-24', '2019-09-25', '2019-09-26',
#                '2019-09-27', '2019-09-30'],
#               dtype='datetime64[ns]', name='Date', length=219, freq=None)

# %%
pd.read_csv("new_text_file.txt",index_col=0,parse_dates=True).index
# Out:
# DatetimeIndex(['2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22',
#                '2018-11-23', '2018-11-26', '2018-11-27', '2018-11-28',
#                '2018-11-29', '2018-11-30',
#                ...
#                '2019-09-17', '2019-09-18', '2019-09-19', '2019-09-20',
#                '2019-09-23', '2019-09-24', '2019-09-25', '2019-09-26',
#                '2019-09-27', '2019-09-30'],
#               dtype='datetime64[ns]', name='Date', length=219, freq=None)

# %%
df4
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-20  61.50
# 2018-11-21  61.65
# 2018-11-22  61.11
# 2018-11-23  57.69
# ...           ...
# 2019-09-24  64.13
# 2019-09-25  62.41
# 2019-09-26  62.08
# 2019-09-27  62.48
# 2019-09-30  60.99
#
# [219 rows x 1 columns]

# %%
df4.loc['2019-09-03']
# Out:
# Price    57.93
# Name: 2019-09-03 00:00:00, dtype: float64

# %%
df4.loc['2019-07-03':'2019-09-03']
# Out:
#             Price
# Date
# 2019-07-03  63.53
# 2019-07-04  63.62
# 2019-07-05  64.23
# 2019-07-08  64.89
# 2019-07-09  64.30
# 2019-07-10  66.41
# 2019-07-11  67.64
# 2019-07-12  66.65
# 2019-07-15  66.86
# 2019-07-16  65.87
# 2019-07-17  63.67
# 2019-07-18  60.70
# 2019-07-19  61.04
# 2019-07-22  61.96
# 2019-07-23  62.28
# 2019-07-24  63.83
# 2019-07-25  63.47
# 2019-07-26  62.46
# 2019-07-29  62.29
# 2019-07-30  62.55
# 2019-07-31  64.07
# 2019-08-01  62.90
# 2019-08-02  61.12
# 2019-08-05  59.32
# 2019-08-06  58.63
# 2019-08-07  55.03
# 2019-08-08  56.29
# 2019-08-09  57.37
# 2019-08-12  57.13
# 2019-08-13  59.90
# 2019-08-14  57.86
# 2019-08-15  57.37
# 2019-08-16  59.00
# 2019-08-19  59.79
# 2019-08-20  59.03
# 2019-08-21  60.60
# 2019-08-22  59.81
# 2019-08-23  58.64
# 2019-08-26  58.64
# 2019-08-27  58.44
# 2019-08-28  60.42
# 2019-08-29  60.59
# 2019-08-30  61.04
# 2019-09-02  58.55
# 2019-09-03  57.93

# %%
df4.loc['2019-09']
# Out:
#             Price
# Date
# 2019-09-02  58.55
# 2019-09-03  57.93
# 2019-09-04  60.68
# 2019-09-05  62.70
# 2019-09-06  61.28
# 2019-09-09  63.99
# 2019-09-10  64.67
# 2019-09-11  63.02
# 2019-09-12  60.76
# 2019-09-13  61.25
# 2019-09-16  68.42
# 2019-09-17  65.59
# 2019-09-18  64.29
# 2019-09-19  64.25
# 2019-09-20  65.23
# 2019-09-23  64.66
# 2019-09-24  64.13
# 2019-09-25  62.41
# 2019-09-26  62.08
# 2019-09-27  62.48
# 2019-09-30  60.99

# %%
df4.loc['dec 2018':'march 2019'].std()
# Out:
# Price    4.254587
# dtype: float64

# %%
df4.loc['dec 2018':'march 2019'].mean()
# Out:
# Price    61.878625
# dtype: float64

# %%
df4.loc['dec 2018':'march 2019'].median()
# Out:
# Price    61.875
# dtype: float64

# %%
df4.loc['feb 2019'].mean() > df4.loc['july 2019'].mean()
# Out:
# Price    True
# dtype: bool

# %%
df4.index.quarter
# Out:
# Int64Index([4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#             ...
#             3, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#            dtype='int64', name='Date', length=219)

# %%
df4.index.month
# Out:
# Int64Index([11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#             ...
#              9,  9,  9,  9,  9,  9,  9,  9,  9,  9],
#            dtype='int64', name='Date', length=219)

# %%
df4.index.day_name()
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday',
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        ...
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday', 'Tuesday',
#        'Wednesday', 'Thursday', 'Friday', 'Monday'],
#       dtype='object', name='Date', length=219)

# %%
import pandas as pd

# %%
pd.date_range(start='10 may 2022', end='10 aug 2022')
# Out:
# DatetimeIndex(['2022-05-10', '2022-05-11', '2022-05-12', '2022-05-13',
#                '2022-05-14', '2022-05-15', '2022-05-16', '2022-05-17',
#                '2022-05-18', '2022-05-19', '2022-05-20', '2022-05-21',
#                '2022-05-22', '2022-05-23', '2022-05-24', '2022-05-25',
#                '2022-05-26', '2022-05-27', '2022-05-28', '2022-05-29',
#                '2022-05-30', '2022-05-31', '2022-06-01', '2022-06-02',
#                '2022-06-03', '2022-06-04', '2022-06-05', '2022-06-06',
#                '2022-06-07', '2022-06-08', '2022-06-09', '2022-06-10',
#                '2022-06-11', '2022-06-12', '2022-06-13', '2022-06-14',
#                '2022-06-15', '2022-06-16', '2022-06-17', '2022-06-18',
#                '2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28', '2022-06-29', '2022-06-30',
# ...

# %%
pd.date_range('5/5/2022','20 june 2022')
# Out:
# DatetimeIndex(['2022-05-05', '2022-05-06', '2022-05-07', '2022-05-08',
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-14', '2022-05-15', '2022-05-16',
#                '2022-05-17', '2022-05-18', '2022-05-19', '2022-05-20',
#                '2022-05-21', '2022-05-22', '2022-05-23', '2022-05-24',
#                '2022-05-25', '2022-05-26', '2022-05-27', '2022-05-28',
#                '2022-05-29', '2022-05-30', '2022-05-31', '2022-06-01',
#                '2022-06-02', '2022-06-03', '2022-06-04', '2022-06-05',
#                '2022-06-06', '2022-06-07', '2022-06-08', '2022-06-09',
#                '2022-06-10', '2022-06-11', '2022-06-12', '2022-06-13',
#                '2022-06-14', '2022-06-15', '2022-06-16', '2022-06-17',
#                '2022-06-18', '2022-06-19', '2022-06-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='1/12/2020', periods=10, freq='2W')
# Out:
# DatetimeIndex(['2020-01-12', '2020-01-26', '2020-02-09', '2020-02-23',
#                '2020-03-08', '2020-03-22', '2020-04-05', '2020-04-19',
#                '2020-05-03', '2020-05-17'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
pd.date_range(end='1/12/2020', periods=10, freq='2W')
# Out:
# DatetimeIndex(['2019-09-08', '2019-09-22', '2019-10-06', '2019-10-20',
#                '2019-11-03', '2019-11-17', '2019-12-01', '2019-12-15',
#                '2019-12-29', '2020-01-12'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
pd.date_range(start='1/12/2020', periods=10, freq='M')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
dob= pd.Timestamp('2020-03-09')

# %%
dob-pd.DateOffset(days=18)
# Out:
# Timestamp('2020-02-20 00:00:00')

# %%
pd.DateOffset(days=4, minutes=10, nanoseconds=2)
# Out:
# <DateOffset: days=4, minutes=10, nanoseconds=2>

# %%
pd.DateOffset(year=10)
# Out:
# <DateOffset: year=10>

# %%
df4.head()
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-20  61.50
# 2018-11-21  61.65
# 2018-11-22  61.11
# 2018-11-23  57.69

# %%
df4.set_index(df4.index + pd.DateOffset(hours=17))
# Out:
#                      Price
# Date
# 2018-11-19 17:00:00  64.14
# 2018-11-20 17:00:00  61.50
# 2018-11-21 17:00:00  61.65
# 2018-11-22 17:00:00  61.11
# 2018-11-23 17:00:00  57.69
# ...                    ...
# 2019-09-24 17:00:00  64.13
# 2019-09-25 17:00:00  62.41
# 2019-09-26 17:00:00  62.08
# 2019-09-27 17:00:00  62.48
# 2019-09-30 17:00:00  60.99
#
# [219 rows x 1 columns]

# %%
df4
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-20  61.50
# 2018-11-21  61.65
# 2018-11-22  61.11
# 2018-11-23  57.69
# ...           ...
# 2019-09-24  64.13
# 2019-09-25  62.41
# 2019-09-26  62.08
# 2019-09-27  62.48
# 2019-09-30  60.99
#
# [219 rows x 1 columns]

# %%
df4.resample('M').sum()
# Out:
#               Price
# Date
# 2018-11-30   599.34
# 2018-12-31   975.16
# 2019-01-31  1307.01
# 2019-02-28  1279.21
# 2019-03-31  1388.91
# 2019-04-30  1495.90
# 2019-05-31  1568.99
# 2019-06-30  1284.41
# 2019-07-31  1470.14
# 2019-08-31  1298.92
# 2019-09-30  1319.36

# %%
import seaborn as sns

# %%
df4.resample('Y').median().plot();

# %%
df4
# Out:
#           Date  Price
# 0   2018-11-19  64.14
# 1   2018-11-20  61.50
# 2   2018-11-21  61.65
# 3   2018-11-22  61.11
# 4   2018-11-23  57.69
# ..         ...    ...
# 214 2019-09-24  64.13
# 215 2019-09-25  62.41
# 216 2019-09-26  62.08
# 217 2019-09-27  62.48
# 218 2019-09-30  60.99
#
# [219 rows x 2 columns]

# %%
df4
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-20  61.50
# 2018-11-21  61.65
# 2018-11-22  61.11
# 2018-11-23  57.69
# ...           ...
# 2019-09-24  64.13
# 2019-09-25  62.41
# 2019-09-26  62.08
# 2019-09-27  62.48
# 2019-09-30  60.99
#
# [219 rows x 1 columns]

# %%
df4
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-20  61.50
# 2018-11-21  61.65
# 2018-11-22  61.11
# 2018-11-23  57.69
# ...           ...
# 2019-09-24  64.13
# 2019-09-25  62.41
# 2019-09-26  62.08
# 2019-09-27  62.48
# 2019-09-30  60.99
#
# [219 rows x 1 columns]

# %%
df4.resample('8H').interpolate(method='akima')
# Out:
#                          Price
# Date
# 2018-11-19 00:00:00  64.140000
# 2018-11-19 08:00:00  62.887644
# 2018-11-19 16:00:00  61.945287
# 2018-11-20 00:00:00  61.500000
# 2018-11-20 08:00:00  61.493196
# ...                        ...
# 2019-09-28 16:00:00  61.999444
# 2019-09-29 00:00:00  61.795764
# 2019-09-29 08:00:00  61.558873
# 2019-09-29 16:00:00  61.289907
# 2019-09-30 00:00:00  60.990000
#
# [946 rows x 1 columns]

# %%
df4.resample('8H').interpolate(method='linear')
# Out:
#                          Price
# Date
# 2018-11-19 00:00:00  64.140000
# 2018-11-19 08:00:00  63.260000
# 2018-11-19 16:00:00  62.380000
# 2018-11-20 00:00:00  61.500000
# 2018-11-20 08:00:00  61.550000
# ...                        ...
# 2019-09-28 16:00:00  61.652222
# 2019-09-29 00:00:00  61.486667
# 2019-09-29 08:00:00  61.321111
# 2019-09-29 16:00:00  61.155556
# 2019-09-30 00:00:00  60.990000
#
# [946 rows x 1 columns]

# %%
df4.resample('8H').interpolate(method='spline',order=3)
# Out:
#                          Price
# Date
# 2018-11-19 00:00:00  64.140000
# 2018-11-19 08:00:00  63.256312
# 2018-11-19 16:00:00  62.765250
# 2018-11-20 00:00:00  61.500000
# 2018-11-20 08:00:00  61.882885
# ...                        ...
# 2019-09-28 16:00:00  61.428798
# 2019-09-29 00:00:00  61.305730
# 2019-09-29 08:00:00  61.189427
# 2019-09-29 16:00:00  61.080461
# 2019-09-30 00:00:00  60.990000
#
# [946 rows x 1 columns]

# %%
df4.asfreq('10D')
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-29  58.29
# 2018-12-09    NaN
# 2018-12-19  55.60
# 2018-12-29    NaN
# 2019-01-08  56.91
# 2019-01-18  62.04
# 2019-01-28  59.71
# 2019-02-07  61.01
# 2019-02-17    NaN
# 2019-02-27  65.55
# 2019-03-09    NaN
# 2019-03-19  67.13
# 2019-03-29  67.93
# 2019-04-08  71.12
# 2019-04-18  70.71
# 2019-04-28    NaN
# 2019-05-08  71.09
# 2019-05-18    NaN
# 2019-05-28  70.19
# 2019-06-07  64.10
# 2019-06-17  62.56
# 2019-06-27  66.78
# 2019-07-07    NaN
# 2019-07-17  63.67
# 2019-07-27    NaN
# 2019-08-06  58.63
# 2019-08-16  59.00
# 2019-08-26  58.64
# 2019-09-05  62.70
# 2019-09-15    NaN
# 2019-09-25  62.41

# %%
df4.asfreq('10D',fill_value=df4.values.mean())
# Out:
#                 Price
# Date
# 2018-11-19  64.140000
# 2018-11-29  58.290000
# 2018-12-09  63.869178
# 2018-12-19  55.600000
# 2018-12-29  63.869178
# 2019-01-08  56.910000
# 2019-01-18  62.040000
# 2019-01-28  59.710000
# 2019-02-07  61.010000
# 2019-02-17  63.869178
# 2019-02-27  65.550000
# 2019-03-09  63.869178
# 2019-03-19  67.130000
# 2019-03-29  67.930000
# 2019-04-08  71.120000
# 2019-04-18  70.710000
# 2019-04-28  63.869178
# 2019-05-08  71.090000
# 2019-05-18  63.869178
# 2019-05-28  70.190000
# 2019-06-07  64.100000
# 2019-06-17  62.560000
# 2019-06-27  66.780000
# 2019-07-07  63.869178
# 2019-07-17  63.670000
# 2019-07-27  63.869178
# 2019-08-06  58.630000
# 2019-08-16  59.000000
# 2019-08-26  58.640000
# 2019-09-05  62.700000
# 2019-09-15  63.869178
# 2019-09-25  62.410000

# %%
df4
# Out:
#             Price
# Date
# 2018-11-19  64.14
# 2018-11-20  61.50
# 2018-11-21  61.65
# 2018-11-22  61.11
# 2018-11-23  57.69
# ...           ...
# 2019-09-24  64.13
# 2019-09-25  62.41
# 2019-09-26  62.08
# 2019-09-27  62.48
# 2019-09-30  60.99
#
# [219 rows x 1 columns]

# %%
df4.rolling(3).mean()
# Out:
#                 Price
# Date
# 2018-11-19        NaN
# 2018-11-20        NaN
# 2018-11-21  62.430000
# 2018-11-22  61.420000
# 2018-11-23  60.150000
# ...               ...
# 2019-09-24  64.673333
# 2019-09-25  63.733333
# 2019-09-26  62.873333
# 2019-09-27  62.323333
# 2019-09-30  61.850000
#
# [219 rows x 1 columns]
